# %%
#ML - Classification - Naive bayes - Algorithm

# %% [markdown]
# Problem Statement:
#
# Develop a machine learning model to predict whether a customer will respond to a marketing campaign based on demographic information, income, purchasing behavior, and website activity. The objective is to help businesses identify customers who are most likely to respond, thereby improving campaign effectiveness and reducing marketing costs.

# %%
#1.IMPORTING REQUIRED LIBRARIES
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import numpy as np              → Loads numpy, used for numerical operations and arrays
#import matplotlib.pyplot as plt → Loads matplotlib's plotting module, used to create graphs and charts
#import pandas as pd             → Loads pandas, used to work with data in table form

#These three libraries together let us handle numbers, data tables, and visualizations.

# %%
#2.LOADING AND VIEWING THE DATASET
dataset=pd.read_csv("superstore_data.csv") 
dataset

#pd.read_csv("superstore_data.csv")   → Reads data from the CSV file into a table format
#dataset = ...                          → Stores this data table in a variable called dataset
#dataset                                 → Displays the dataset so we can view its contents

#This loads the superstore data from a CSV file and shows it as a table.
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
#3.REMOVING UNNEEDED COLUMNS
dataset.drop(['Id', 'Dt_Customer'], axis=1, inplace=True)
dataset

#dataset.drop(['Id', 'Dt_Customer'], axis=1, inplace=True)   → Removes the 'Id' and 'Dt_Customer' columns from the dataset
#axis=1                                                        → Tells pandas we're dropping columns (not rows)
#inplace=True                                                  → Directly updates dataset without needing to reassign it
#dataset                                                        → Displays the updated dataset

#These columns aren't useful for the model, so they're removed to keep the data clean.
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0           1970  Graduation       Divorced  84835.0        0         0
# 1           1961  Graduation         Single  57091.0        0         0
# 2           1958  Graduation        Married  67267.0        0         1
# 3           1967  Graduation       Together  32474.0        1         1
# 4           1989  Graduation         Single  21474.0        1         0
# ...          ...         ...            ...      ...      ...       ...
# 2235        1976         PhD       Divorced  66476.0        0         1
# 2236        1977    2n Cycle        Married  31056.0        1         0
# 2237        1976  Graduation       Divorced  46310.0        1         0
# 2238        1978  Graduation        Married  65819.0        0         0
# 2239        1969         PhD        Married  94871.0        0         2
#
#       Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# ...

# %%
#4.CONVERTING CATEGORICAL COLUMNS INTO NUMBERS
dataset=pd.get_dummies(dataset,drop_first=True)
dataset

#pd.get_dummies(dataset, drop_first=True)   → Converts categorical (text) columns into numeric 0/1 columns
#drop_first=True                              → Drops the first category of each column to avoid duplicate/redundant info
#dataset = ...                                 → Stores the updated dataset with numeric columns
#dataset                                        → Displays the updated dataset

#Machine learning models need numbers, so this converts text categories into 0s and 1s.
# Out:
#       Year_Birth   Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0           1970  84835.0        0         0        0       189        104
# 1           1961  57091.0        0         0        0       464          5
# 2           1958  67267.0        0         1        0       134         11
# 3           1967  32474.0        1         1        0        10          0
# 4           1989  21474.0        1         0        0         6         16
# ...          ...      ...      ...       ...      ...       ...        ...
# 2235        1976  66476.0        0         1       99       372         18
# 2236        1977  31056.0        1         0       99         5         10
# 2237        1976  46310.0        1         0       99       185          2
# 2238        1978  65819.0        0         0       99       267         38
# 2239        1969  94871.0        0         2       99       169         24
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  ...  \
# ...

# %%
#5.CHECKING THE BALANCE OF THE TARGET VARIABLE
dataset["Response"].value_counts() #To Identify Balanced or Imbalanced Value Counts

#dataset["Response"].value_counts()   → Counts how many times each unique value appears in the "Response" column

#This checks whether the target column is balanced (similar counts) or imbalanced (one value is much more common than the other).
# Out:
# Response
# 0    1906
# 1     334
# Name: count, dtype: int64

# %%
#6.SPLITTING DATA INTO INPUT (X) AND OUTPUT (Y)
indep=dataset[["Income", "Kidhome", "Teenhome", "Recency", "MntWines"]]
dep=dataset["Response"]

#dataset[[...]]   → Selects multiple columns from the dataset to use as input features
#indep = ...        → Stores these selected columns as the independent variables (inputs)
#dataset["Response"]   → Selects the "Response" column, which is what we want to predict
#dep = ...              → Stores this column as the dependent variable (output)

#This separates the data into inputs (indep) and the target we want to predict (dep).

# %%
#7.CHECKING THE SHAPE OF INPUT DATA
indep.shape

#indep.shape   → Shows the number of rows and columns in indep

#This confirms how many samples and features are present in the input data.
# Out:
# (2240, 5)

# %%
#8.DISPLAYING THE TARGET VARIABLE
dep

#dep   → Displays the values stored in dep, the target variable

#This shows the actual output/target values used for training the model.
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 2235    0
# 2236    0
# 2237    0
# 2238    0
# 2239    1
# Name: Response, Length: 2240, dtype: int64

# %%
#9.CHECKING NULL VALUES IN INPUT DATA
print(indep.isnull().sum())

#indep.isnull().sum()   → Counts the number of missing (null) values in each column of indep

#This checks whether the input features have any missing values before training the model.
# Out:
# Income      24
# Kidhome      0
# Teenhome     0
# Recency      0
# MntWines     0
# dtype: int64

# %%
#10.HANDLING MISSING VALUES USING SIMPLEIMPUTER
from sklearn.impute import SimpleImputer
import numpy as np

imputer = SimpleImputer(strategy='mean')  
indep_imputed = imputer.fit_transform(indep)

#from sklearn.impute import SimpleImputer   → Imports the tool used to fill in missing values
#import numpy as np                          → Imports numpy for numerical operations
#SimpleImputer(strategy='mean')              → Creates an imputer that fills missing values with the column's mean
#imputer = ...                                → Stores this imputer object
#imputer.fit_transform(indep)                → Learns the mean of each column and fills in missing values in indep
#indep_imputed = ...                          → Stores the updated data with missing values filled in

#This replaces missing values in the data with the average (mean) of each column, so the model can be trained without errors.

# %%
#11.SPLITTING AND SCALING THE DATA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(indep_imputed, dep, test_size=0.2, random_state=0)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#from sklearn.model_selection import train_test_split   → Imports the tool used to split data
#from sklearn.preprocessing import StandardScaler       → Imports the tool used to scale data
#train_test_split(indep_imputed, dep, test_size=0.2, random_state=0)   → Splits data into training and testing sets
#test_size=0.2                                            → Uses 20% of the data for testing, rest for training
#random_state=0                                           → Ensures the same split every time the code runs
#X_train, X_test, y_train, y_test = ...                    → Stores the training inputs, testing inputs, training outputs, testing outputs
#scaler = StandardScaler()                                → Creates a scaler object
#scaler.fit_transform(X_train)                            → Learns the scaling from X_train and applies it
#X_train = ...                                             → Stores the scaled training data
#scaler.transform(X_test)                                 → Applies the same scaling to X_test
#X_test = ...                                              → Stores the scaled testing data

#This splits the cleaned data into training and testing sets, then scales both so all features are on a similar range.

# %%
#12.TRAINING A NAIVE BAYES CLASSIFIER
from sklearn.naive_bayes import GaussianNB  #These first two lines are called as a procedure
classifier =GaussianNB() 
classifier.fit(X_train, y_train) #Fit - Called Function. X-input, Y-output

#from sklearn.naive_bayes import GaussianNB   → Imports the Gaussian Naive Bayes classifier model
#GaussianNB()                                   → Creates a Naive Bayes model, assuming features follow a normal distribution
#classifier = ...                                → Stores this model
#classifier.fit(X_train, y_train)                → Trains the model using the training inputs and outputs

#This trains a Naive Bayes model, which predicts outcomes based on probability using the training data.
# Out:
# GaussianNB()

# %%
#13.MAKING PREDICTIONS ON TEST DATA
y_pred = classifier.predict(X_test)

#classifier.predict(X_test)   → Uses the trained Naive Bayes model to predict outputs for the test data
#y_pred = ...                   → Stores these predicted values

#This generates predictions on unseen test data using the trained model.

# %%
#14.EVALUATING THE NAIVE BAYES MODEL
from sklearn.metrics import confusion_matrix #Confusion Matrix Identification
cm = confusion_matrix(y_test, y_pred)

from sklearn.metrics import classification_report #Classification Report
clf_report = classification_report(y_test, y_pred)

#from sklearn.metrics import confusion_matrix   → Imports the tool to build a confusion matrix
#confusion_matrix(y_test, y_pred)                 → Compares actual vs predicted values in a matrix form
#cm = ...                                          → Stores the confusion matrix
#from sklearn.metrics import classification_report   → Imports the tool to generate a classification report
#classification_report(y_test, y_pred)                → Creates a report showing precision, recall, F1-score, etc.
#clf_report = ...                                      → Stores the classification report

#This checks how well the Naive Bayes model performs on unseen test data, using a confusion matrix and classification report.

# %%
#15.PRINTING THE CLASSIFICATION REPORT
print(clf_report)

#print(clf_report)   → Displays the classification report

#This shows precision, recall, and F1-score for each class from the Naive Bayes model's evaluation.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       384
#            1       0.52      0.41      0.46        64
#
#     accuracy                           0.86       448
#    macro avg       0.71      0.67      0.69       448
# weighted avg       0.85      0.86      0.85       448

# %%
#16.PRINTING THE CONFUSION MATRIX
print(cm)

#print(cm)   → Displays the confusion matrix

#This shows the confusion matrix comparing actual vs predicted values from the Naive Bayes model.
# Out:
# [[360  24]
#  [ 38  26]]

# %%
#17.TRAINING A MULTINOMIAL NAIVE BAYES CLASSIFIER
from sklearn.naive_bayes import MultinomialNB  #These first two lines are called as a procedure
classifier = MultinomialNB () 
classifier.fit(X_train, y_train) #Fit - Called Function. X-input, Y-output

#from sklearn.naive_bayes import MultinomialNB   → Imports the Multinomial Naive Bayes classifier model
#MultinomialNB()                                   → Creates a Naive Bayes model suited for count-based or frequency-based features
#classifier = ...                                   → Stores this model
#classifier.fit(X_train, y_train)                   → Trains the model using the training inputs and outputs

#This trains a Multinomial Naive Bayes model, commonly used when features represent counts or frequencies (like word counts).
# Out:
# MultinomialNB()

# %%
#18.MAKING PREDICTIONS ON TEST DATA
y_pred = classifier.predict(X_test)

#classifier.predict(X_test)   → Uses the trained model to predict outputs for the test data
#y_pred = ...                   → Stores these predicted values

#This generates predictions on unseen test data using the trained model.

# %%
#19.EVALUATING THE MULTINOMIAL NAIVE BAYES MODEL
from sklearn.metrics import confusion_matrix #Confusion Matrix Identification
cm = confusion_matrix(y_test, y_pred)

from sklearn.metrics import classification_report #Classification Report
clf_report = classification_report(y_test, y_pred)

#from sklearn.metrics import confusion_matrix   → Imports the tool to build a confusion matrix
#confusion_matrix(y_test, y_pred)                 → Compares actual vs predicted values in a matrix form
#cm = ...                                          → Stores the confusion matrix
#from sklearn.metrics import classification_report   → Imports the tool to generate a classification report
#classification_report(y_test, y_pred)                → Creates a report showing precision, recall, F1-score, etc.
#clf_report = ...                                      → Stores the classification report

#This checks how well the Multinomial Naive Bayes model performs on unseen test data, using a confusion matrix and classification report.
# Out:
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
#20.PRINTING THE CLASSIFICATION REPORT
print(clf_report)

#print(clf_report)   → Displays the classification report

#This shows precision, recall, and F1-score for each class from the model's evaluation.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       384
#            1       0.00      0.00      0.00        64
#
#     accuracy                           0.86       448
#    macro avg       0.43      0.50      0.46       448
# weighted avg       0.73      0.86      0.79       448

# %%
#21.PRINTING THE CONFUSION MATRIX
print(cm)

#print(cm)   → Displays the confusion matrix

#This shows the confusion matrix comparing actual vs predicted values from the model.
# Out:
# [[384   0]
#  [ 64   0]]

# %%
#22.TRAINING A BERNOULLI NAIVE BAYES CLASSIFIER
from sklearn.naive_bayes import BernoulliNB  #These first two lines are called as a procedure
classifier = BernoulliNB () 
classifier.fit(X_train, y_train) #Fit - Called Function. X-input, Y-output 

#from sklearn.naive_bayes import BernoulliNB   → Imports the Bernoulli Naive Bayes classifier model
#BernoulliNB()                                   → Creates a Naive Bayes model suited for binary (0/1) features
#classifier = ...                                 → Stores this model
#classifier.fit(X_train, y_train)                 → Trains the model using the training inputs and outputs

#This trains a Bernoulli Naive Bayes model, commonly used when features are binary (yes/no, 0/1 type values).
# Out:
# BernoulliNB()

# %%
#23.MAKING PREDICTIONS ON TEST DATA
y_pred = classifier.predict(X_test)

#classifier.predict(X_test)   → Uses the trained model to predict outputs for the test data
#y_pred = ...                   → Stores these predicted values

#This generates predictions on unseen test data using the trained model.

# %%
#24.EVALUATING THE BERNOULLI NAIVE BAYES MODEL
from sklearn.metrics import confusion_matrix #Confusion Matrix Identification
cm = confusion_matrix(y_test, y_pred)

from sklearn.metrics import classification_report #Classification Report
clf_report = classification_report(y_test, y_pred)

#from sklearn.metrics import confusion_matrix   → Imports the tool to build a confusion matrix
#confusion_matrix(y_test, y_pred)                 → Compares actual vs predicted values in a matrix form
#cm = ...                                          → Stores the confusion matrix
#from sklearn.metrics import classification_report   → Imports the tool to generate a classification report
#classification_report(y_test, y_pred)                → Creates a report showing precision, recall, F1-score, etc.
#clf_report = ...                                      → Stores the classification report

#This checks how well the Bernoulli Naive Bayes model performs on unseen test data, using a confusion matrix and classification report.
# Out:
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
#25.PRINTING THE CLASSIFICATION REPORT
print(clf_report)

#print(clf_report)   → Displays the classification report

#This shows precision, recall, and F1-score for each class from the model's evaluation.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       384
#            1       0.00      0.00      0.00        64
#
#     accuracy                           0.86       448
#    macro avg       0.43      0.50      0.46       448
# weighted avg       0.73      0.86      0.79       448

# %%
#26. PRINTING THE CONFUSION MATRIX
print(cm)

#print(cm)   → Displays the confusion matrix

#This shows the confusion matrix comparing actual vs predicted values from the model.
# Out:
# [[384   0]
#  [ 64   0]]

# %%
#27.TRAINING A CATEGORICAL NAIVE BAYES CLASSIFIER
from sklearn.naive_bayes import CategoricalNB  #These first two lines are called as a procedure
classifier = CategoricalNB () 
classifier.fit(X_train, y_train) #Fit - Called Function. X-input, Y-output 

#from sklearn.naive_bayes import CategoricalNB   → Imports the Categorical Naive Bayes classifier model
#CategoricalNB()                                   → Creates a Naive Bayes model suited for categorical (discrete) features
#classifier = ...                                   → Stores this model
#classifier.fit(X_train, y_train)                   → Trains the model using the training inputs and outputs

#This trains a Categorical Naive Bayes model, commonly used when features represent distinct categories rather than continuous numbers.
# Out:
# CategoricalNB()

# %%
#28.MAKING PREDICTIONS ON TEST DATA
y_pred = classifier.predict(X_test)

#classifier.predict(X_test)   → Uses the trained model to predict outputs for the test data
#y_pred = ...                   → Stores these predicted values

#This generates predictions on unseen test data using the trained model.

# %%
#29.EVALUATING THE CATEGORICAL NAIVE BAYES MODEL
from sklearn.metrics import confusion_matrix #Confusion Matrix Identification
cm = confusion_matrix(y_test, y_pred)

from sklearn.metrics import classification_report #Classification Report
clf_report = classification_report(y_test, y_pred)

#from sklearn.metrics import confusion_matrix   → Imports the tool to build a confusion matrix
#confusion_matrix(y_test, y_pred)                 → Compares actual vs predicted values in a matrix form
#cm = ...                                          → Stores the confusion matrix
#from sklearn.metrics import classification_report   → Imports the tool to generate a classification report
#classification_report(y_test, y_pred)                → Creates a report showing precision, recall, F1-score, etc.
#clf_report = ...                                      → Stores the classification report

#This checks how well the Categorical Naive Bayes model performs on unseen test data, using a confusion matrix and classification report.
# Out:
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
#30.PRINTING THE CLASSIFICATION REPORT
print(clf_report)

#print(clf_report)   → Displays the classification report

#This shows precision, recall, and F1-score for each class from the model's evaluation.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       384
#            1       0.00      0.00      0.00        64
#
#     accuracy                           0.86       448
#    macro avg       0.43      0.50      0.46       448
# weighted avg       0.73      0.86      0.79       448

# %%
#31.PRINTING THE CONFUSION MATRIX
print(cm)

#print(cm)   → Displays the confusion matrix

#This shows the confusion matrix comparing actual vs predicted values from the model.
# Out:
# [[384   0]
#  [ 64   0]]

# %%
#32.TRAINING A COMPLEMENT NAIVE BAYES CLASSIFIER
from sklearn.naive_bayes import ComplementNB  #These first two lines are called as a procedure
classifier = ComplementNB () 
classifier.fit(X_train, y_train) #Fit - Called Function. X-input, Y-output 

#from sklearn.naive_bayes import ComplementNB   → Imports the Complement Naive Bayes classifier model
#ComplementNB()                                   → Creates a Naive Bayes model designed to work well with imbalanced datasets
#classifier = ...                                  → Stores this model
#classifier.fit(X_train, y_train)                  → Trains the model using the training inputs and outputs

#This trains a Complement Naive Bayes model, often better suited than standard Naive Bayes when classes are imbalanced.
# Out:
# ComplementNB()

# %%
#33.MAKING PREDICTIONS ON TEST DATA
y_pred = classifier.predict(X_test)

#classifier.predict(X_test)   → Uses the trained model to predict outputs for the test data
#y_pred = ...                   → Stores these predicted values

#This generates predictions on unseen test data using the trained model.

# %%
#34.EVALUATING THE COMPLEMENT NAIVE BAYES MODEL
from sklearn.metrics import confusion_matrix #Confusion Matrix Identification
cm = confusion_matrix(y_test, y_pred)

from sklearn.metrics import classification_report #Classification Report
clf_report = classification_report(y_test, y_pred)

#from sklearn.metrics import confusion_matrix   → Imports the tool to build a confusion matrix
#confusion_matrix(y_test, y_pred)                 → Compares actual vs predicted values in a matrix form
#cm = ...                                          → Stores the confusion matrix
#from sklearn.metrics import classification_report   → Imports the tool to generate a classification report
#classification_report(y_test, y_pred)                → Creates a report showing precision, recall, F1-score, etc.
#clf_report = ...                                      → Stores the classification report

#This checks how well the Complement Naive Bayes model performs on unseen test data, using a confusion matrix and classification report.

# %%
#35.PRINTING THE CLASSIFICATION REPORT
print(clf_report)

#print(clf_report)   → Displays the classification report

#This shows precision, recall, and F1-score for each class from the model's evaluation.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82       384
#            1       0.30      0.70      0.42        64
#
#     accuracy                           0.73       448
#    macro avg       0.62      0.72      0.62       448
# weighted avg       0.85      0.73      0.76       448

# %%
#36.PRINTING THE CONFUSION MATRIX
print(cm)

#print(cm)   → Displays the confusion matrix

#This shows the confusion matrix comparing actual vs predicted values from the model.
# Out:
# [[281 103]
#  [ 19  45]]

# %%
#37.SAVING THE TRAINED MODEL

import pickle  #How to save model
filename = "finalized_model_superstore_data.csv_Classification.sav"  #File name must be in .sav in the last

#import pickle   → Loads the pickle library, used to save the trained model to a file
#filename = "finalized_model_superstore_data.csv_Classification.sav"   → Sets the name of the file where the model will be saved
#filename must end in .sav                                              → Naming convention used so the file is recognized as a saved model

#This sets up the file name where the trained model will be saved for future use, without needing to retrain it.

# %%
#38.SAVING THE TRAINED MODEL TO A FILE
pickle.dump(classifier, open(filename, 'wb'))

#open(filename, 'wb')          → Opens the file in "write binary" mode, needed to save the model
#pickle.dump(classifier, ...)  → Saves the trained model (classifier) into that file

#This saves the trained model to disk, so it can be loaded and reused later without retraining.

# %%
#39.LOADING THE SAVED MODEL AND MAKING A PREDICTION
loaded_model = pickle.load(open("finalized_model_superstore_data.csv_Classification.sav", 'rb'))  
result = loaded_model.predict([[84835, 0, 0, 0, 189]]) 

#pickle.load(open("finalized_model_superstore_data.csv_Classification.sav", 'rb'))   → Loads the saved trained model back from file
#loaded_model = ...                                                                    → Stores the loaded model
#loaded_model.predict([[84835, 0, 0, 0, 189]])                                        → Uses the loaded model to predict an outcome for this new data
#result = ...                                                                          → Stores the predicted result

#This loads the model we already trained and saved, then uses it to predict new data — without retraining.

# %%
#40.DISPLAYING THE PREDICTION RESULT
result

#result   → Displays the predicted outcome from the model

#This shows the final prediction made using the saved model and new input values.
# Out:
# array([1])
